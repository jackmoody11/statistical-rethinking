# %%
import numpy as np
import matplotlib.pyplot as plt

# 4M1
n_simulations = 1000
mu = np.random.normal(0, 10, n_simulations)
sigma = np.random.exponential(1)
y = np.random.normal(mu, sigma)
plt.hist(y)
# Out:
# (array([  1.,   2.,  30.,  86., 193., 285., 230., 125.,  41.,   7.]),
#  array([-40.28595409, -33.3216626 , -26.3573711 , -19.3930796 ,
#         -12.42878811,  -5.46449661,   1.49979488,   8.46408638,
#          15.42837788,  22.39266937,  29.35696087]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 4M3
#
#
# $y_i \sim \text{Normal}(\mu, \sigma)$
#
# $\mu \sim a + b \cdot x$
#
# $a \sim \text{Normal}(0, 10)$
#
# $b \sim \text{Uniform}(0, 1)$
#
# $\sigma \sim \text{Exponential}(1)$
